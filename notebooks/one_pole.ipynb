# %%
# from matplotlib import pyplot as plt 
# import math
# import numpy as np

# SR=48e3

# a0 = 0
# b1 = 0
# z1 = 0

# def set_cutoff(cutoff: float):
#     freq = cutoff / SR
#     b1 = math.exp(-2 * math.pi * freq)
#     a0 = 1.0 - b1

# def next(input: float):
#     z = input * a0 + z1 * b1
#     return z

# set_cutoff(440.0)

# sin_x = np.arange(0, 5 * math.pi, 0.1)
# sin_y = np.sin(sin_x)
# plt.plot(sin_x, sin_y)

# flt_y = [next(val) for val in sin_y]
# plt.plot(sin_x, flt_y)

# plt.show()
